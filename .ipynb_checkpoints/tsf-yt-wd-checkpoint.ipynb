# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import jpholiday

import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('demand.csv')
df.head()
df = df.set_index('datetime')
df.index = pd.to_datetime(df.index , format='%m/%d/%Y %H:%M')
df = df.rename(columns={ 'actual_performance(10000 kW)': 'demand'})

# %%
prefecture_files = {
    'osaka': 'osaka.csv',
    'hikone': 'hikone.csv',
    'kyoto': 'kyoto.csv',
    'kobe': 'kobe.csv',
    'shionomisaki': 'shionomisaki.csv',
    'toyooka': 'toyooka.csv',
    'wakayama': 'wakayama.csv'
}
weather_weights = {
    'osaka': 0.25,
    'hikone': 0.15,
    'kyoto': 0.2,
    'kobe': 0.15,
    'shionomisaki': 0.1,
    'toyooka': 0.1,
    'wakayama': 0.05
}

prefecture_dfs = {}
for prefecture, file in prefecture_files.items():
    pdf = pd.read_csv(file)
    pdf['datetime'] = pd.to_datetime(pdf['datetime'])
    prefecture_dfs[prefecture] = pdf


weather_vars = [
    'precipitation',
    'temperature',
    'dew_point_temperature',
    'humidity',
    'wind_speed',
    'snowfall'
]

wind_mapping = {
    "北": 0,
    "北北東": 22.5,
    "北東": 45,
    "東": 90,
    "南東": 135,
    "南": 180,
    "南西": 225,
    "西": 270,
    "北西": 315,
    "西南西": 247.5,
}

# %%
for prefecture, df in prefecture_dfs.items():
    df['wind_direction'] = df['wind_direction'].map(wind_mapping)
    df['wind_direction'] = pd.to_numeric(df['wind_direction'], errors='coerce')

# %%
base_pref = 'osaka'
aggregated_weather = prefecture_dfs[base_pref][['datetime']].copy()

# Initialize columns
for var in weather_vars:
    aggregated_weather[var] = 0.0
aggregated_weather['wind_direction'] = 0.0

# %%
# Accumulate weighted sums
for prefecture, w in weather_weights.items():
    # Merge on datetime
    merged_temp = pd.merge(
        aggregated_weather,
        prefecture_dfs[prefecture],
        on='datetime',
        how='left',
        suffixes=('', '_temp')
    )

    # For each weather variable, add weighted value
    for var in weather_vars:
        merged_temp[var] = merged_temp[var] + w * merged_temp[f'{var}_temp']

    # # Weighted wind_direction (encoded or numeric)
    merged_temp['wind_direction'] = merged_temp['wind_direction'] + w * merged_temp['wind_direction_temp']

    # Clean up extra columns
    drop_cols = [f'{var}_temp' for var in weather_vars] + ['wind_direction_temp']
    merged_temp.drop(columns=drop_cols, inplace=True)

    aggregated_weather = merged_temp

# Round wind_direction if needed
# aggregated_weather['wind_direction'] = aggregated_weather['wind_direction'].round().astype(int)
aggregated_weather['wind_direction']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 26275   NaN
# 26276   NaN
# 26277   NaN
# 26278   NaN
# 26279   NaN
# Name: wind_direction, Length: 26280, dtype: float64

# %%
#  Merge the Aggregated Weather with Demand
merged_df = pd.merge(df, aggregated_weather, on='datetime', how='left')

merged_df
# Out:
#                  datetime  demand  precipitation  temperature  \
# 0     2021-01-01 00:00:00    1571          0.050        1.725
# 1     2021-01-01 01:00:00    1492          0.150        1.815
# 2     2021-01-01 02:00:00    1453          0.050        1.715
# 3     2021-01-01 03:00:00    1412          0.100        1.370
# 4     2021-01-01 04:00:00    1358          0.050        1.575
# ...                   ...     ...            ...          ...
# 26275 2023-12-31 19:00:00    1427          0.500       10.610
# 26276 2023-12-31 20:00:00    1392          0.650       10.360
# 26277 2023-12-31 21:00:00    1348          0.350        9.735
# 26278 2023-12-31 22:00:00    1288          1.125        9.435
# 26279 2023-12-31 23:00:00    1258          0.275        9.595
#
#        dew_point_temperature  humidity  wind_speed  snowfall  wind_direction
# 0                     -3.825     67.35       4.055       0.1               0
# 1                     -3.645     67.75       3.575       0.2               0
# 2                     -3.695     67.95       3.530       0.0               0
# 3                     -3.685     69.75       3.465       0.2               0
# 4                     -3.265     70.80       3.330       0.0               0
# ...                      ...       ...         ...       ...             ...
# 26275                  4.310     65.95       5.040       0.0               0
# 26276                  4.170     65.85       5.500       0.0               0
# 26277                  4.910     72.60       4.730       0.0               0
# 26278                  5.435     76.40       4.720       0.0               0
# 26279                  5.550     75.95       3.930       0.0               0
#
# [26280 rows x 9 columns]

# %%
df = merged_df.copy()
df = df.set_index('datetime')
df
# Out:
#                      demand  precipitation  temperature  \
# datetime
# 2021-01-01 00:00:00    1571          0.050        1.725
# 2021-01-01 01:00:00    1492          0.150        1.815
# 2021-01-01 02:00:00    1453          0.050        1.715
# 2021-01-01 03:00:00    1412          0.100        1.370
# 2021-01-01 04:00:00    1358          0.050        1.575
# ...                     ...            ...          ...
# 2023-12-31 19:00:00    1427          0.500       10.610
# 2023-12-31 20:00:00    1392          0.650       10.360
# 2023-12-31 21:00:00    1348          0.350        9.735
# 2023-12-31 22:00:00    1288          1.125        9.435
# 2023-12-31 23:00:00    1258          0.275        9.595
#
#                      dew_point_temperature  humidity  wind_speed  snowfall  \
# datetime
# 2021-01-01 00:00:00                 -3.825     67.35       4.055       0.1
# 2021-01-01 01:00:00                 -3.645     67.75       3.575       0.2
# 2021-01-01 02:00:00                 -3.695     67.95       3.530       0.0
# 2021-01-01 03:00:00                 -3.685     69.75       3.465       0.2
# 2021-01-01 04:00:00                 -3.265     70.80       3.330       0.0
# ...                                    ...       ...         ...       ...
# 2023-12-31 19:00:00                  4.310     65.95       5.040       0.0
# 2023-12-31 20:00:00                  4.170     65.85       5.500       0.0
# 2023-12-31 21:00:00                  4.910     72.60       4.730       0.0
# 2023-12-31 22:00:00                  5.435     76.40       4.720       0.0
# 2023-12-31 23:00:00                  5.550     75.95       3.930       0.0
#
#                      wind_direction
# datetime
# 2021-01-01 00:00:00               0
# 2021-01-01 01:00:00               0
# 2021-01-01 02:00:00               0
# 2021-01-01 03:00:00               0
# 2021-01-01 04:00:00               0
# ...                             ...
# 2023-12-31 19:00:00               0
# 2023-12-31 20:00:00               0
# 2023-12-31 21:00:00               0
# 2023-12-31 22:00:00               0
# 2023-12-31 23:00:00               0
#
# [26280 rows x 8 columns]

# %%
df.plot(style = '.', figsize = (15,5), y= 'demand', color= color_pal[0], title = 'Hourly Electricity Demand from 2021 to 2023')
plt.show()

# %%
#Train/Test split

train = df.loc[df.index <= '04-30-2023']
test = df.loc[df.index > '04-30-2023']

fig, ax = plt.subplots(figsize = (15,5))
train.plot(ax = ax, y= 'demand', label = 'Training Set', title = 'Train/Test Data split')
test.plot(ax = ax, y= 'demand', label = 'Test Set')
ax.axvline('04-30-2023', color = 'black', ls = '--')
plt.show()

# %%
df.loc[(df.index > '01-01-2021') & (df.index < '01-07-2021')].plot(figsize = (15,5),y= 'demand', title = 'Data of a week')
# Out:
# <Axes: title={'center': 'Data of a week'}, xlabel='datetime'>

# %%
#Feature Creation
def create_features(df):

    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    return df

df = create_features(df)

# %%
# Creating holiday/weekend features
def create_holiday_features(df):

    df = df.copy()
    
    # Basic holiday indicators
    df['is_holiday'] = df.index.map(lambda x: jpholiday.is_holiday(x)).astype(int)
    df['is_weekend'] = df.index.dayofweek.isin([5,6]).astype(int)
    
    return df

df = create_holiday_features(df)

# %%
#Visualise the Feature/Target Relationship
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data = df, x = 'hour', y='demand')
ax.set_title('Demand by Hour')
# Out:
# Text(0.5, 1.0, 'Demand by Hour')

# %%
#Visualise the Feature/Target Relationship
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data = df, x = 'month', y='demand')
ax.set_title('Demand by month')
# Out:
# Text(0.5, 1.0, 'Demand by month')

# %%
df.columns
# Out:
# Index(['demand', 'precipitation', 'temperature', 'dew_point_temperature',
#        'humidity', 'wind_speed', 'snowfall', 'wind_direction', 'hour',
#        'dayofweek', 'quarter', 'month', 'year', 'dayofyear', 'is_holiday',
#        'is_weekend'],
#       dtype='object')

# %%
#Creating our Model

train = create_features(train)
test = create_features(test)

train = create_holiday_features(train)
test = create_holiday_features(test)

FEATURES = ['precipitation', 'temperature', 'dew_point_temperature',
       'humidity', 'wind_speed', 'snowfall','wind_direction','hour', 'dayofweek', 'quarter', 'month', 'year', 'dayofyear', 'is_holiday', 'is_weekend']
TARGET = 'demand'

# %%
X_train = train[FEATURES]
Y_train = train[TARGET]

X_test = test[FEATURES]
Y_test = test[TARGET]

# %%
reg = xgb.XGBRegressor(learning_rate=0.01,
    n_estimators=2000,
    max_depth=8,  # Increased to capture holiday patterns
    subsample=0.8,
    colsample_bytree=0.8,
    early_stopping_rounds=100)

reg.fit(X_train, Y_train,
       eval_set = [(X_train, Y_train), (X_test, Y_test)],
       verbose = 100)
# Out:
# [0]	validation_0-rmse:319.97731	validation_1-rmse:345.91012
# [100]	validation_0-rmse:142.96133	validation_1-rmse:157.11633
# [200]	validation_0-rmse:76.69943	validation_1-rmse:97.26400
# [300]	validation_0-rmse:50.03588	validation_1-rmse:80.16855
# [400]	validation_0-rmse:38.28650	validation_1-rmse:73.71741
# [500]	validation_0-rmse:32.11294	validation_1-rmse:70.05288
# [600]	validation_0-rmse:28.17964	validation_1-rmse:67.76879
# [700]	validation_0-rmse:25.55202	validation_1-rmse:66.38698
# [800]	validation_0-rmse:23.79221	validation_1-rmse:65.49231
# [900]	validation_0-rmse:22.17543	validation_1-rmse:64.95795
# [1000]	validation_0-rmse:20.90867	validation_1-rmse:64.60064
# [1100]	validation_0-rmse:19.78539	validation_1-rmse:64.32329
# [1200]	validation_0-rmse:18.74225	validation_1-rmse:64.14408
# [1300]	validation_0-rmse:17.80450	validation_1-rmse:64.02511
# [1400]	validation_0-rmse:16.96931	validation_1-rmse:63.93240
# [1500]	validation_0-rmse:16.20575	validation_1-rmse:63.87367
# [1600]	validation_0-rmse:15.50525	validation_1-rmse:63.79934
# [1700]	validation_0-rmse:14.88562	validation_1-rmse:63.67438
# [1800]	validation_0-rmse:14.29872	validation_1-rmse:63.61363
# [1900]	validation_0-rmse:13.77476	validation_1-rmse:63.55109
# [1999]	validation_0-rmse:13.29587	validation_1-rmse:63.54041
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=100,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
fimp = pd.DataFrame(data = reg.feature_importances_,
            index = reg.feature_names_in_,
            columns = ['importance'])

fimp.sort_values('importance').plot(kind = 'barh', title = 'Feature Importance')
# Out:
# <Axes: title={'center': 'Feature Importance'}>

# %%
test['prediction'] = reg.predict(X_test)

df = df.merge(test[['prediction']], how = 'left', left_index = True, right_index = True)

# %%
ax = df['demand'].plot(figsize = (15,5))
df['prediction'].plot(ax = ax, style = '.')
plt.legend(['Truth Data', 'Prediction Data'])
ax.set_title('Raw Data and Predicted Data')
# Out:
# Text(0.5, 1.0, 'Raw Data and Predicted Data')

# %%
ax = df.loc[(df.index > '05-11-2023') & (df.index < '05-17-2023')]['demand'].plot(figsize = (15,5))
df.loc[(df.index > '05-11-2023') & (df.index < '05-17-2023')]['prediction'].plot(ax = ax, style = '--')
plt.legend(['Truth Data', 'Prediction Data'])
ax.set_title('Data of a week')
# Out:
# Text(0.5, 1.0, 'Data of a week')

# %%
score = np.sqrt(mean_squared_error(test['demand'], test['prediction']))
print(f'RMSE score on Test set : {score:0.2f}')
# Out:
# RMSE score on Test set : 62.53

# %%
test['error'] = np.abs(test[TARGET] -test['prediction'])

test['date'] = test.index.date
test.groupby('date')['error'].mean().sort_values(ascending = True).head(10)
# Out:
# date
# 2023-05-11     8.041824
# 2023-05-09     8.559886
# 2023-12-06     9.649770
# 2023-05-16    11.501836
# 2023-10-01    12.938873
# 2023-05-19    13.040034
# 2023-05-14    13.325363
# 2023-05-10    13.350311
# 2023-12-08    13.605235
# 2023-12-04    14.059789
# Name: error, dtype: float64

# %%
test.groupby('date')['error'].mean().sort_values(ascending = False).head(5)
# Out:
# date
# 2023-08-15    391.047541
# 2023-08-14    271.286250
# 2023-08-16    192.768133
# 2023-08-21    115.458567
# 2023-08-17    115.133911
# Name: error, dtype: float64
